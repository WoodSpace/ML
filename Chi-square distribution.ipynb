# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
from statsmodels.distributions.empirical_distribution import ECDF
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Распределение хи-квадрат

# %%
# зададим степени свободы
k = 3
# хи-квадрат распределение
chi_square_rv = sts.chi2(k)
sample = rv.rvs(1000)
x = np.linspace(0,10,100)
pdf = chi_square_rv.pdf(x)

# %%
plt.hist(sample, bins=25, normed=True)
plt.plot(x, pdf, label='theoretical pdf', alpha=1)
plt.show()

# %% [markdown]
# Математическое ожидание теоретического распределения равно $k$. Дисперсия равна $2k$

# %%
mean = k 
std = 2 * k

print('Математическое ожидание теоретического распределения:', mean)
print('Стандартное отклонение теоретического распределения:', std)
# Out:
# Математическое ожидание теоретического распределения: 3
# Стандартное отклонение теоретического распределения: 6

# %% [markdown]
# ## Генерация выборок размером : 5, 10, 50

# %% [markdown]
# ### При n = 5

# %%
n = 5
sample_5 = np.array([np.mean(chi_square_rv.rvs(n)) for i in range(1000)])

norm_rv = sts.norm(mean_theor, np.sqrt(std_theor / n))
x = np.linspace(0,10,100)
norm_pdf = norm_rv.pdf(x)

plt.hist(sample_5, bins=15, normed=True, label='hist n=5')
plt.plot(x, norm_pdf, label='theoretical norm', alpha=1)
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.legend()
plt.show()

# %% [markdown]
# ### При n = 10

# %%
n = 10
sample_10 = np.array([np.mean(chi_square_rv.rvs(n)) for i in range(1000)])

norm_rv = sts.norm(mean_theor, np.sqrt(std_theor / n))
x = np.linspace(0,10,100)
norm_pdf = norm_rv.pdf(x)

plt.hist(sample_10, bins=15, normed=True, label='hist n=5')
plt.plot(x, norm_pdf, label='theoretical norm', alpha=1)
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.legend()
plt.show()

# %% [markdown]
# ### При n = 50

# %%
n = 50
sample_50 = np.array([np.mean(chi_square_rv.rvs(n)) for i in range(1000)])

norm_rv = sts.norm(mean_theor, np.sqrt(std_theor / n))
x = np.linspace(0,10,100)
norm_pdf = norm_rv.pdf(x)

plt.hist(sample_50, bins=25, normed=True, label='hist n=5')
plt.plot(x, norm_pdf, label='theoretical norm', alpha=1)
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.legend()
plt.show()

# %% [markdown]
# Вывод: по графикам видно, что с ростом размера выборки выборочные средние приближаются к теоретически расчитанному значению (нормальным распределением), согласно ЦПТ
